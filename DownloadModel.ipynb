# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# %mkdir -p MuseTalk

# %%
# %cd MuseTalk

# %%
# %pwd

# %%
# !pip install -U gdown
# !gdown --folder https://drive.google.com/drive/folders/1ZePnw7IOCg8R-0JyfGYf7ptPdyJhNb_Y?usp=sharing
